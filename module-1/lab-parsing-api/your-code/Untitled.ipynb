# %%
import requests

url = "https://rapidapi.p.rapidapi.com/search"

querystring = {"q":"music","part":"snippet,id","order":"date","regionCode":"US","maxResults":"50"}

headers = {
    'x-rapidapi-host': "youtube-v31.p.rapidapi.com",
    'x-rapidapi-key': "b0c1559f8bmshd42c0af0e3ad872p183a73jsn84668fdebaa7"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#   "kind": "youtube#searchListResponse",
#   "nextPageToken": "CDIQAA",
#   "regionCode": "US",
#   "pageInfo": {
#     "totalResults": 1000000,
#     "resultsPerPage": 50
#   },
#   "items": [
#     {
#       "kind": "youtube#searchResult",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "bhnxEnbSUpw"
#       },
#       "snippet": {
#         "publishedAt": "2020-10-26T22:20:21Z",
#         "channelId": "UCaCE5pzy49M8nQ59plgmFOA",
#         "title": "Tuesday Morning Jazz - Good Mood Jazz and Bossa Nova Music for Happy Day",
#         "description": "The Best 24/7 Radio Live Stream of Tuesday Morning Jazz! Enjoy Good Mood Jazz and Bossa Nova Music for Happy Day by Richard Freeman Spotify: ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/bhnxEnbSUpw/default_live.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
# ...
