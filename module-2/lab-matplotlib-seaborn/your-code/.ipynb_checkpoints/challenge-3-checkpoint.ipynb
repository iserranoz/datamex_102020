# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %%
for i in titanic.columns:
    print(i,len(titanic[i].unique()))
#para analiziar cuales puedo tomar como categorías
# Out:
# PassengerId 1309
# Survived 3
# Pclass 3
# Name 1307
# Gender 2
# Age 193
# SibSp 7
# Parch 8
# Ticket 929
# Fare 281
# Cabin 187
# Embarked 3

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic['Age'] = titanic['Age'].astype(int)
numerical = titanic[['Age','Fare']]

# %%
#your code here- categorical variable
titanic['Survived'] = titanic['Survived'].fillna(0).astype(int)
categorical = titanic[['Survived','Pclass','Gender','Age','SibSp','Parch','Embarked']]

# %%
#descartamos name, ticket y cabin

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
import matplotlib.style
plt.style.use('classic')

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
print(numerical['Age'].mean(), numerical['Age'].min(), numerical['Age'].max())
# Out:
# 29.747135217723454 0 80

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
bins = [10,20,50]
color = ['red','blue','green']
for i in range(3):
    
    titanic['Age'].hist(bins=bins[i],color = color[i])
    plt.show();

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
#por el nuemero de rangos ya que tenemos fechas de 0 a 100 o más

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
bins = [10,20,50]
color = ['r','b','g']
for i in range(3):
    
    ax = sns.distplot(numerical['Age'], bins = bins[i], color = color[i], kde = True)
    ax.axvline(x = numerical['Age'].mean(), c = 'k', linestyle = '--', label = 'media')
    print('BINS: ',bins[i])
    ax.legend()
    plt.show();
# Out:
# BINS:  10
# BINS:  20
# BINS:  50

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
titanic['Gender'].value_counts().plot(kind = 'barh', color = ['blue','pink'])

# %%
# your code here- 2nd way
sns.countplot(titanic['Gender'],data=titanic)

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
titanic['Pclass'].value_counts().plot(kind = 'pie')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
fig, ax = plt.subplots()
ax.hist(titanic['Age'], bins = 30)
ax.set_xlabel('Age')
ax.set_ylabel('Freq')
plt.axvline(np.mean(titanic['Age']), c = 'r', linestyle = '--', label = 'meedia')
plt.axvline(np.mean(titanic['Age']) + np.std(titanic['Age']), c = 'k', linestyle = '--', label = '1-desviacion')
plt.axvline(np.mean(titanic['Age']) - np.std(titanic['Age']), c = 'k', linestyle = '--', label = '1-desviacion')
plt.axvline(np.mean(titanic['Age']) + 2*np.std(titanic['Age']), c = 'k', linestyle = '-', label = '2-desviacion')
plt.axvline(np.mean(titanic['Age']) - 2*np.std(titanic['Age']), c = 'k', linestyle = '-', label = '2-desviacion')
ax.legend()

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
# que la mayoría de los valores se concentran entre 15 aproximadamente y 55 años
#y que tenemos muchoas valores de cero probablmente atípicos

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
sns.boxplot(y = titanic['Age'],orient="h",color='r')

plt.show;

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
#tal vez mi rango se acorta a 20-40, co atípicos mayores a 60

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way

fig, ax = plt.subplots()
ax.scatter(titanic['Fare'] ,titanic['Age'], c = 'r')
ax.set_xlabel('Fare')
ax.set_ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
# your code-2nd way
sns.scatterplot(data=titanic, x="Fare", y="Age")

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
corr = titanic.corr()
sns.heatmap(corr,cmap="YlGnBu")
plt.title('Matriz de correlación')
# Out:
# Text(0.5, 1, 'Matriz de correlación')

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
#correlaciones fuertes entre Pclass y Age, entre fare y Pclass

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
fig, ax = plt.subplots()
sns.boxplot(x = 'Pclass', y = 'Age', data = titanic)

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
facet = sns.FacetGrid(titanic, col="Gender")
facet.map(plt.hist, "Age")
