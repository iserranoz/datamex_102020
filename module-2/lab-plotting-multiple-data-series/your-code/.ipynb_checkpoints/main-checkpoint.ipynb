# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
import numpy as np

# %%
data = pd.read_csv('liquor_store_sales.csv')
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128355 entries, 0 to 128354
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Year             128355 non-null  int64
#  1   Month            128355 non-null  int64
#  2   Supplier         128331 non-null  object
#  3   ItemCode         128355 non-null  object
#  4   Description      128355 non-null  object
#  5   ItemType         128354 non-null  object
#  6   RetailSales      128355 non-null  float64
#  7   RetailTransfers  128355 non-null  float64
#  8   WarehouseSales   128355 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 8.8+ MB

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
pd.pivot_table(data, index = ['ItemType'], 
               values = ['RetailSales','RetailTransfers','WarehouseSales'], aggfunc = sum)
# Out:
#               RetailSales  RetailTransfers  WarehouseSales
# ItemType
# BEER            209763.11        234924.44      2437617.32
# DUNNAGE              0.00             0.00       -45331.00
# KEGS                 0.00             0.00        43558.00
# LIQUOR          309847.85        334176.41        33173.32
# NON-ALCOHOL       8109.97          9058.37         8656.72
# REF                281.34           171.92        -6754.00
# STR_SUPPLIES       995.98          3594.70            0.00
# WINE            313400.42        340710.51       433009.47

# %%
pd.pivot_table(data, index = ['ItemType'], 
               values = ['RetailSales','RetailTransfers','WarehouseSales'], aggfunc = sum).plot.bar(figsize = (10,5))

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
data['Total Sales'] = data.RetailSales + data.RetailTransfers + data.WarehouseSales
pd.pivot_table(data, index = ['Supplier'], values = 'Total Sales', aggfunc = sum).sort_values(by ='Total Sales', ascending = False).head(10).plot.bar()

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
mes = pd.pivot_table(data, index = 'Month', values = ['RetailSales','RetailTransfers','WarehouseSales'],aggfunc = np.mean)

# %%
mes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 1 to 12
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RetailSales      10 non-null     float64
#  1   RetailTransfers  10 non-null     float64
#  2   WarehouseSales   10 non-null     float64
# dtypes: float64(3)
# memory usage: 320.0 bytes

# %%
mes.plot(figsize=(15,6));

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
mes.plot.bar()

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
m_y = pd.crosstab([data['Year'], data['Month']],columns = data['ItemType'],
           values = data['RetailSales'], aggfunc= sum)

# %%
m_y
# Out:
# ItemType        BEER  DUNNAGE  KEGS    LIQUOR  NON-ALCOHOL    REF  \
# Year Month
# 2017 4          0.00      NaN   NaN      0.00         0.00   0.00
#      5      25023.24      NaN   NaN  35123.36          NaN    NaN
#      6      27863.26      0.0   0.0  35035.31      1209.23  30.60
#      8      23030.13      0.0   0.0  32186.04      1091.28  19.54
#      9      23852.76      0.0   0.0  32532.32       997.11  38.88
#      10     22583.78      0.0   0.0  32491.59       945.63  22.82
#      11     23341.14      0.0   0.0  35524.77      1005.19  63.11
#      12     28822.16      0.0   0.0  49522.28      1316.44  41.21
# 2018 1      16606.33      0.0   0.0  28579.87       732.25  23.66
#      2      18640.31      0.0   0.0  28852.31       812.84  41.52
#
# ItemType    STR_SUPPLIES      WINE
# Year Month
# 2017 4              0.00      0.00
#      5               NaN  34546.89
#      6             89.22  33129.64
#      8             77.34  30707.45
# ...

# %%
g = m_y.cumsum()

# %%
m_y.plot( figsize = (10,5))

# %%
g.plot( figsize = (10,5))

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
g.plot.bar(figsize = (10,5))

# %%
m_y.plot.bar(figsize = (10,5))

# %%
# no entendí si había que hacer la suma acumulada o no por eso las dos

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128355 entries, 0 to 128354
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Year             128355 non-null  int64
#  1   Month            128355 non-null  int64
#  2   Supplier         128331 non-null  object
#  3   ItemCode         128355 non-null  object
#  4   Description      128355 non-null  object
#  5   ItemType         128354 non-null  object
#  6   RetailSales      128355 non-null  float64
#  7   RetailTransfers  128355 non-null  float64
#  8   WarehouseSales   128355 non-null  float64
#  9   Total Sales      128355 non-null  float64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 9.8+ MB

# %%
sns.scatterplot(data=data, x='RetailSales', y='RetailTransfers', hue="ItemType")

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
import seaborn as sns

# %%
sns.pairplot(data[['RetailSales','RetailTransfers','WarehouseSales','ItemType']], hue="ItemType", diag_kind="hist")
